# %%
# !pip install deepxde
# Out:
# /bin/bash: pip: command not found

# %%
import deepxde
# Out:
# No backend selected.
# Finding available backend...
# Cannot find available backend.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: No available backend found.
# Please manually install a backend, and run DeepXDE again.
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3678: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
